-- %% [markdown]
-- # National Health and Nutrition Examination Survey (NHANES)
-- [https://wwwn.cdc.gov/nchs/nhanes/](https://wwwn.cdc.gov/nchs/nhanes/)
--
-- Este laboratório usará dados extraídos do NHANES.
--
-- ## NHANES datasets from 2013-2014
--
-- Foram extraídos dados do [NHANES 2013-2014](https://wwwn.cdc.gov/nchs/nhanes/continuousnhanes/default.aspx?BeginYear=2013).
--
-- Os dados estão disponíveis em arquivos CSV no diretório `/data/nhanes`. Lá está disponível a documentação do esquema dos arquivos.

-- %% [markdown]
-- # Tarefa 1 - Esquema Relacional
--
-- Analise os arquivos CSV que estão no diretório `/data/nhanes` e escreva um esquema relacional referente às tabelas, suas chaves primárias e estrangeiras (não é SQL ainda). Coloque a chave primária com dois underlines antes e dois depois:
--
-- \__teste\__

-- %% [markdown]
-- - Pessoa (__id__, gender, age)
-- - Droga (__code__, name)
-- - Uso_medicamento (__person_id, drug_code__, days_use)
--  - __person_id__ é chave estrangeira para Pessoa
--  - __drug_code__ é chave estrangeira para Droga

-- %% [markdown]
-- ## Criação das Tabelas em SQL e Importação de Dados
--
-- Considere o seguinte exemplo em que é criada uma tabela em SQL e importado dados do arquivo CSV `demographic-person.csv`.

-- %%
%defaultDatasource jdbc:h2:mem:db

-- %%
DROP TABLE IF EXISTS Pessoa;
CREATE TABLE Pessoa (
  Id VARCHAR(5) NOT NULL,
  Gender INTEGER,
  Age INTEGER,
  PRIMARY KEY(Id)
) AS SELECT
    id,
    gender,
    age
FROM CSVREAD('../data/demographic-person.csv');

-- %%
SELECT * FROM Pessoa;

-- %% [markdown]
-- # Tarefa 2 - Criação das Tabelas em SQL e Importação de Dados
--
-- Escreva instruções SQL para montar as duas tabelas restante, conforme definido no esquema relacional da **Tarefa 1**.
--
-- **Importante:** não defina chave primária para a tabela de uso de medicamento.
--
-- Durante a criação das tabelas, realize a importação dos dados do arquivo CSV nas tabelas criadas, conforme exemplo anterior.

-- %%
DROP TABLE IF EXISTS Droga;
CREATE TABLE Droga (
  Code VARCHAR(6) NOT NULL,
  Name VARCHAR(100) NOT NULL,
  PRIMARY KEY(Code)
) AS SELECT
    code,
    name
FROM CSVREAD('../data/medications-drug.csv');

-- %%
SELECT * FROM Droga;

-- %%
DROP TABLE IF EXISTS Uso_medicamento;
CREATE TABLE Uso_medicamento (
  Person_id VARCHAR(5) NOT NULL,
  Drug_code VARCHAR(6) NOT NULL,
  Days_use INT,
  FOREIGN KEY(Person_id)
    REFERENCES Pessoa(Id)
    ON DELETE NO ACTION
    ON UPDATE NO ACTION,
  FOREIGN KEY(Drug_code)
    REFERENCES Droga(Code)
    ON DELETE NO ACTION
    ON UPDATE NO ACTION
) AS SELECT
    person_id,
    drug_code,
    days_use
FROM CSVREAD('../data/medications-use.csv');

-- %%
SELECT * FROM Uso_medicamento;

-- %% [markdown]
-- # Tarefa 3 - Consultas Simples
--
-- Execute as consultas a seguir.

-- %% [markdown]
-- a) Liste pessoas com idade acima de 60

-- %%
SELECT * FROM Pessoa WHERE Pessoa.Age > 60

-- %% [markdown]
-- b) Liste as idades das pessoas cadastradas (sem repetições)

-- %%
SELECT DISTINCT P.Age FROM Pessoa P

-- %% [markdown]
-- c) Liste código das pessoas, idade, código dos medicamentos que usaram e dias de uso

-- %%
SELECT P.Id, P.Age, D.Code, U.Days_use 
FROM Pessoa P, Droga D, Uso_medicamento U
WHERE P.Id = U.Person_id AND D.Code = U.Drug_code

-- %% [markdown]
-- d) Liste código das Pessoas, idade, nome dos medicamentos que usaram e quantos dias de uso

-- %%
SELECT P.Id, P.Age, D.Name, U.Days_use 
FROM Pessoa P, Droga D, Uso_medicamento U
WHERE P.Id = U.Person_id AND D.Code = U.Drug_code

-- %% [markdown]
-- e) Liste nome dos medicamentos que foram usados por pessoas (sem repetições)

-- %%
SELECT DISTINCT D.Name FROM Droga D, Uso_medicamento U WHERE D.Code = U.Drug_code

-- %% [markdown]
-- f) Liste nome dos medicamentos usados por mais de 2.000 dias (sem repetições)

-- %%
SELECT DISTINCT D.Name
FROM Pessoa P, Droga D, Uso_medicamento U
WHERE P.Id = U.Person_id AND D.Code = U.Drug_code AND U.Days_use > 2000
